# %%
import random
import matplotlib.pyplot as plt
import pandas as pd

# %%
#100번 마다 확률을 저장하는 리스트
#100, 200, 300, 400, 500... 100000
res1 = []
res2 = []
res3 = []

prob = []
idx = []


for i in range(100, 50001, 100):
    count1 = 0
    count2 = 0
    count3 = 0
    for j in range(i):
        r = random.randint(1,3)
        if  r== 1:
            count1 = count1 + 1
        elif r==2:
            count2 = count2 + 1
        else:
            count3 = count3 + 1
        
    res1.append(count1/i*100)
    res2.append(count2/i*100)
    res3.append(count3/i*100)
    
    idx.append(i)

# %%
table = {'1':res1, '2':res2, '3':res3}
dfr = pd.DataFrame(table, columns=['1', '2', '3'])

# %%
dfr
# Out:
#              1          2          3
# 0    31.000000  30.000000  39.000000
# 1    35.000000  33.000000  32.000000
# 2    31.333333  35.333333  33.333333
# 3    34.000000  37.000000  29.000000
# 4    31.800000  30.600000  37.600000
# ..         ...        ...        ...
# 495  33.423387  33.191532  33.385081
# 496  33.503018  33.173038  33.323944
# 497  32.819277  33.487952  33.692771
# 498  33.150301  33.232465  33.617234
# 499  33.478000  33.196000  33.326000
#
# [500 rows x 3 columns]

# %%
dfr.plot( grid= True, title='1,2,3 random%')
plt.show()

# %%
data = ['goat', 'car', 'goat']
#참가자는 셋중 하나를 선택한다.
#사회자는 같은 확률로 goat가 있는 문을 연다.
#그리고 참가자는 선택을 바꿀지 결정한다.
#이 모델에서 확률은 2/3로 바꾸는 것이 car 당첨 확률이 더 높은지 비교해보자

res_c = []
res_s = []
k = 1
#1부터 100까자 1씩 증가
for i in range(1, 101):
    
    #i번 돌려본다.
    change_count = 0
    stay_count = 0
    for j in range(1, i):
        
        print(k,": start")
        k = k + 1
        #각 회차마다 data에는 ['car', 'goat', 'goat']의 순서가 바뀐다.
        data = random.sample(data, 3)
        print(data)
        #랜덤으로 숫자를 문을 고르고
        your_choice = random.randint(0,2)
        print("내 선택: ", your_choice)
        #사회자가 문을 열기 위한 선택지
        option = [0 , 1 , 2]
        
        #참가자가 고른 선택지는 제외한다.
        option.remove(your_choice)
        print("내 선택 후 남은 문: ",option)
        #그 후 남은 두 문 중 사회자는 보여줄 문을 선택하는데
        open_number = random.sample(option, 2)
        if data[open_number[0]] == 'car':
            option.remove(open_number[1])
        else:
            option.remove(open_number[0])
            
        print("오픈 할 문: ", option)
        
        #바꿨을 때 확률
        if data[option[0]] == 'car':
            change_count = change_count + 1
        
        #유지 했을 때 확률
        elif data[your_choice] == 'car':
            stay_count = stay_count + 1
        print("stop\n\n")
        
        
    res_c.append(change_count/i*100)
    res_s.append(stay_count/i*100)
# Out:
# 1 : start
# ['car', 'goat', 'goat']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [2]
# stop
#
#
# 2 : start
# ['goat', 'goat', 'car']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [2]
# stop
#
#
# 3 : start
# ['goat', 'goat', 'car']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [2]
# stop
#
#
# 4 : start
# ['car', 'goat', 'goat']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [0]
# stop
#
#
# 5 : start
# ['car', 'goat', 'goat']
# 내 선택:  1
# 내 선택 후 남은 문:  [0, 2]
# 오픈 할 문:  [0]
# stop
#
#
# 6 : start
# ['goat', 'car', 'goat']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [1]
# stop
#
#
# 7 : start
# ['car', 'goat', 'goat']
# 내 선택:  1
# 내 선택 후 남은 문:  [0, 2]
# 오픈 할 문:  [0]
# stop
#
#
# 8 : start
# ['goat', 'goat', 'car']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [2]
# stop
#
#
# 9 : start
# ['goat', 'car', 'goat']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [1]
# stop
#
#
# 10 : start
# ['goat', 'goat', 'car']
# 내 선택:  1
# 내 선택 후 남은 문:  [0, 2]
# 오픈 할 문:  [2]
# stop
#
#
# 11 : start
# ['goat', 'goat', 'car']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [0]
# stop
#
#
# 12 : start
# ['goat', 'goat', 'car']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [0]
# stop
#
#
# 13 : start
# ['car', 'goat', 'goat']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [1]
# stop
#
#
# 14 : start
# ['goat', 'goat', 'car']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [0]
# stop
#
#
# 15 : start
# ['goat', 'car', 'goat']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [1]
# stop
#
#
# 16 : start
# ['car', 'goat', 'goat']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [0]
# stop
#
#
# 17 : start
# ['goat', 'goat', 'car']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [0]
# stop
#
#
# 18 : start
# ['car', 'goat', 'goat']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [1]
# stop
#
#
# 19 : start
# ['car', 'goat', 'goat']
# 내 선택:  1
# 내 선택 후 남은 문:  [0, 2]
# 오픈 할 문:  [0]
# stop
#
#
# 20 : start
# ['goat', 'goat', 'car']
# 내 선택:  1
# 내 선택 후 남은 문:  [0, 2]
# 오픈 할 문:  [2]
# stop
#
#
# 21 : start
# ['car', 'goat', 'goat']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [1]
# stop
#
#
# 22 : start
# ['car', 'goat', 'goat']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [0]
# stop
#
#
# 23 : start
# ['goat', 'car', 'goat']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [1]
# stop
#
#
# 24 : start
# ['goat', 'goat', 'car']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [2]
# stop
#
#
# 25 : start
# ['car', 'goat', 'goat']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [0]
# stop
#
#
# 26 : start
# ['goat', 'goat', 'car']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [1]
# stop
#
#
# 27 : start
# ['car', 'goat', 'goat']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [0]
# stop
#
#
# 28 : start
# ['goat', 'goat', 'car']
# 내 선택:  1
# 내 선택 후 남은 문:  [0, 2]
# 오픈 할 문:  [2]
# stop
#
#
# 29 : start
# ['goat', 'goat', 'car']
# 내 선택:  1
# 내 선택 후 남은 문:  [0, 2]
# 오픈 할 문:  [2]
# stop
#
#
# 30 : start
# ['goat', 'goat', 'car']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [0]
# stop
#
#
# 31 : start
# ['car', 'goat', 'goat']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [0]
# stop
#
#
# 32 : start
# ['car', 'goat', 'goat']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [1]
# stop
#
#
# 33 : start
# ['goat', 'goat', 'car']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [2]
# stop
#
#
# 34 : start
# ['goat', 'car', 'goat']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [1]
# stop
#
#
# 35 : start
# ['car', 'goat', 'goat']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [0]
# stop
#
#
# 36 : start
# ['goat', 'goat', 'car']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [2]
# stop
#
#
# 37 : start
# ['goat', 'goat', 'car']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [2]
# stop
#
#
#
: start
# ['car', 'goat', 'goat']
# 내 선택:  1
# 내 선택 후 남은 문:  [0, 2]
# 오픈 할 문:  [0]
# stop
#
#
# 4946 : start
# ['goat', 'goat', 'car']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [1]
# stop
#
#
# 4947 : start
# ['car', 'goat', 'goat']
# 내 선택:  1
# 내 선택 후 남은 문:  [0, 2]
# 오픈 할 문:  [0]
# stop
#
#
# 4948 : start
# ['goat', 'goat', 'car']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [2]
# stop
#
#
# 4949 : start
# ['goat', 'car', 'goat']
# 내 선택:  0
# 내 선택 후 남은 문:  [1, 2]
# 오픈 할 문:  [1]
# stop
#
#
# 4950 : start
# ['goat', 'car', 'goat']
# 내 선택:  2
# 내 선택 후 남은 문:  [0, 1]
# 오픈 할 문:  [1]
# stop

# %%
repd = pd.DataFrame({'res_c':res_c,'res_s':res_s})
repd
# Out:
#         res_c      res_s
# 0    0.000000   0.000000
# 1    0.000000  50.000000
# 2   66.666667   0.000000
# 3   75.000000   0.000000
# 4   80.000000   0.000000
# ..        ...        ...
# 95  62.500000  36.458333
# 96  68.041237  30.927835
# 97  64.285714  34.693878
# 98  55.555556  43.434343
# 99  69.000000  30.000000
#
# [100 rows x 2 columns]

# %%
repd.plot(grid=True, title="Monty Hall problem sim")
plt.show()

# %%
data = ['goat', 'car', 'goat']
#참가자는 셋중 하나를 선택한다.
#사회자는 같은 확률로 goat가 있는 문을 연다.
#그리고 참가자는 선택을 바꿀지 결정한다.
#이 모델에서 확률은 2/3로 바꾸는 것이 car 당첨 확률이 더 높은지 비교해보자

res_c = []
res_s = []
idx = []
#1부터 10000까자 1씩 증가
for i in range(1, 10001,1):
    #i번 돌려본다.
    change_count = 0
    stay_count = 0
    for j in range(i):
        #각 회차마다 data에는 ['car', 'goat', 'goat']의 순서가 바뀐다.
        data = random.sample(data, 3)
        
        #랜덤으로 숫자를 문을 고르고
        your_choice = random.randint(0,2)
        
        #사회자가 문을 열기 위한 선택지
        option = [0 , 1 , 2]
        
        #참가자가 고른 선택지는 제외한다.
        option.remove(your_choice)
        
        #그 후 남은 두 문 중 사회자는 보여줄 문을 선택하는데
        open_number = random.sample(option, 2)
        if data[open_number[0]] == 'car':
            option.remove(open_number[1])
        else:
            option.remove(open_number[0])
            
        
        #바꿨을 때 확률
        if data[option[0]] == 'car':
            change_count = change_count + 1
        
        #유지 했을 때 확률
        elif data[your_choice] == 'car':
            stay_count = stay_count + 1
        
    idx.append(i)
    res_c.append(change_count/i*100)
    res_s.append(stay_count/i*100)

# %%
redt2 = pd.DataFrame({"res_c":res_c, "ress":res_s,"N":idx})
redt2.set_index('N', inplace= True)
redt2
# Out:
#             res_c       ress
# N
# 1      100.000000   0.000000
# 2      100.000000   0.000000
# 3       66.666667  33.333333
# 4       50.000000  50.000000
# 5       80.000000  20.000000
# ...           ...        ...
# 9996    65.846339  34.153661
# 9997    67.080124  32.919876
# 9998    66.803361  33.196639
# 9999    66.716672  33.283328
# 10000   66.610000  33.390000
#
# [10000 rows x 2 columns]

# %%
redt2.plot(grid=True, title="Monty Hall problem sim")
